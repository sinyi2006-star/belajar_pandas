# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
n_rows = 365 * 24 
n_cols = 2         
cols = ['col1', 'col2'] 

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)

df.index = pd.date_range(start='2023-01-01', periods=n_rows, freq='h')

df.head()
# Out:
#                      col1  col2
# 2023-01-01 00:00:00     2     2
# 2023-01-01 01:00:00    12     3
# 2023-01-01 02:00:00     8    18
# 2023-01-01 03:00:00     9     3
# 2023-01-01 04:00:00     9     1

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_20640\985753190.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample('M')['col1'].sum().to_frame()
#             col1
# 2023-01-31  7364
# 2023-02-28  6513
# 2023-03-31  7354
# 2023-04-30  6821
# 2023-05-31  7569
# 2023-06-30  7309
# 2023-07-31  7565
# 2023-08-31  7479
# 2023-09-30  7010
# 2023-10-31  7420
# 2023-11-30  7216
# 2023-12-31  7534

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2023-01-01   283
# 2023-01-02   207
# 2023-01-03   211
# 2023-01-04   241
# 2023-01-05   238
# ...          ...
# 2023-12-27   252
# 2023-12-28   283
# 2023-12-29   165
# 2023-12-30   249
# 2023-12-31   236
#
# [365 rows x 1 columns]
